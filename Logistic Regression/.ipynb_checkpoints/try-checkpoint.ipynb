# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(n_samples=100, n_features=2, centers=6, cluster_std=0, random_state=5)

# %%
X
# Out:
# array([[-4.06398997, -6.24557543],
#        [-8.38517462,  4.76880592],
#        [-8.38517462,  4.76880592],
#        [-5.56013658,  7.41464612],
#        [-8.38517462,  4.76880592],
#        [-5.86561689,  8.37221816],
#        [-4.06398997, -6.24557543],
#        [ 5.31815713,  0.36835976],
#        [-5.86561689,  8.37221816],
#        [-5.56013658,  7.41464612],
#        [-8.38517462,  4.76880592],
#        [-5.56013658,  7.41464612],
#        [-8.38517462,  4.76880592],
#        [-8.38517462,  4.76880592],
#        [-0.23177622,  2.23487726],
#        [-5.86561689,  8.37221816],
#        [-0.23177622,  2.23487726],
#        [-4.06398997, -6.24557543],
#        [-0.23177622,  2.23487726],
#        [ 5.31815713,  0.36835976],
#        [-4.06398997, -6.24557543],
#        [-0.23177622,  2.23487726],
#        [-5.86561689,  8.37221816],
#        [-8.38517462,  4.76880592],
#        [-8.38517462,  4.76880592],
#        [-0.23177622,  2.23487726],
#        [-5.56013658,  7.41464612],
# ...

# %%
y
# Out:
# array([4, 5, 5, 0, 5, 1, 4, 3, 1, 0, 5, 0, 5, 5, 2, 1, 2, 4, 2, 3, 4, 2,
#        1, 5, 5, 2, 0, 0, 0, 0, 3, 0, 2, 1, 1, 0, 3, 4, 5, 2, 2, 3, 4, 2,
#        1, 1, 5, 1, 3, 0, 0, 0, 4, 2, 5, 3, 5, 3, 3, 2, 0, 4, 5, 4, 0, 4,
#        1, 2, 4, 2, 2, 4, 2, 5, 1, 1, 1, 5, 0, 3, 1, 3, 3, 1, 5, 3, 4, 4,
#        4, 2, 1, 0, 1, 3, 0, 3, 3, 3, 4, 2])

# %%
import matplotlib.pyplot as plt 
import numpy as np
plt.scatter np.(X.ravel() ,y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 3 plt.scatter (np.X.ravel() ,y)
#
# File ~\anaconda3\Lib\site-packages\numpy\__init__.py:333, in __getattr__(attr)
#     330     "Removed in NumPy 1.25.0"
#     331     raise RuntimeError("Tester was removed in NumPy 1.25.")
# --> 333 raise AttributeError("module {!r} has no attribute "
#     334                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'X'
