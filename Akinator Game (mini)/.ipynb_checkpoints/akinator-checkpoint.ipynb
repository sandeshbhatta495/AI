# %%
import pandas as pd

data = {
    "real": [1, 0, 0],
    "male": [1, 1, 1],
    "fictional": [0, 1, 1],
    "movie": [0, 1, 1],
    "sports": [1, 0, 0],
    "character": ["Messi", "IronMan", "HarryPotter"]
}

df = pd.DataFrame(data)
X = df.drop("character", axis=1)
y = df["character"]
