# %%
for t in trees:
    sample data with replacement
    grow decision tree with random features

predict(x):
    predictions = []
    for tree in forest:
        predictions.append(tree.predict(x))
    return vote(predictions)
